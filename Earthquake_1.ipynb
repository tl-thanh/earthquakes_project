# %%
import requests as rq
import json
import datetime
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import time as time
import csv
import os

from datetime import datetime

os.system('touch earthquake_data1.csv')
# Out:
# 1

# %%
# api_key = "AIzaSyDl4Yjdxvn8h12fpIGHn1v2f2i31tCs5eQ"
all_data = []
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2017-01-01&minmagnitude=4.8&maxmagnitude=4.99'
# url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2017-01-01&minmagnitudes=3'
# url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2012-01-02&minmagnitude=5'
earthquake_data = rq.get(url).json()

for i in range(0,len(earthquake_data['features'])):
    all_data.append({'Location':earthquake_data['features'][i]['properties']['place'], 'Magnitude':earthquake_data['features'][i]['properties']['mag'],'UTC_Time':earthquake_data['features'][i]['properties']['time'],'Longitude':earthquake_data['features'][i]['geometry']['coordinates'][0],'Latitude':earthquake_data['features'][i]['geometry']['coordinates'][1], 'Depth':earthquake_data['features'][i]['geometry']['coordinates'][2]})

print(all_data)
# Out:
# [{'Location': '89km ESE of Haebaru, Japan', 'Magnitude': 4.8, 'UTC_Time': 1483218482160, 'Longitude': 128.7113, 'Latitude': 26.058, 'Depth': 8.26}, {'Location': '78km WSW of Banda Aceh, Indonesia', 'Magnitude': 4.9, 'UTC_Time': 1483196482860, 'Longitude': 94.6379, 'Latitude': 5.3647, 'Depth': 67.06}, {'Location': "119km ESE of Yigo Mayor's Office, Guam", 'Magnitude': 4.9, 'UTC_Time': 1483132114060, 'Longitude': 145.9761, 'Latitude': 13.3141, 'Depth': 10}, {'Location': '69km E of Petropavlovsk-Kamchatskiy, Russia', 'Magnitude': 4.9, 'UTC_Time': 1483118003100, 'Longitude': 159.6696, 'Latitude': 52.9299, 'Depth': 64.17}, {'Location': "159km SSW of L'Esperance Rock, New Zealand", 'Magnitude': 4.8, 'UTC_Time': 1483103480780, 'Longitude': -179.6688, 'Latitude': -32.7096, 'Depth': 10}, {'Location': '137km SE of `Ohonua, Tonga', 'Magnitude': 4.8, 'UTC_Time': 1483095583650, 'Longitude': -173.8594, 'Latitude': -22.0388, 'Depth': 10}, {'Location': '204km SSE of Isangel, Vanuatu', 'Magnitude': 4
# ...

# %%
data_df = pd.DataFrame(all_data)
data_df.head()
# Out:
#    Depth  Latitude                                     Location  Longitude  \
# 0   8.26   26.0580                   89km ESE of Haebaru, Japan   128.7113
# 1  67.06    5.3647            78km WSW of Banda Aceh, Indonesia    94.6379
# 2  10.00   13.3141       119km ESE of Yigo Mayor's Office, Guam   145.9761
# 3  64.17   52.9299  69km E of Petropavlovsk-Kamchatskiy, Russia   159.6696
# 4  10.00  -32.7096   159km SSW of L'Esperance Rock, New Zealand  -179.6688
#
#    Magnitude       UTC_Time
# 0        4.8  1483218482160
# 1        4.9  1483196482860
# 2        4.9  1483132114060
# 3        4.9  1483118003100
# 4        4.8  1483103480780

# %%
data_df['Date'] = ''
data_df['Date_Time'] = '' 
data_df.head()
# Out:
#    Depth  Latitude                                     Location  Longitude  \
# 0   8.26   26.0580                   89km ESE of Haebaru, Japan   128.7113
# 1  67.06    5.3647            78km WSW of Banda Aceh, Indonesia    94.6379
# 2  10.00   13.3141       119km ESE of Yigo Mayor's Office, Guam   145.9761
# 3  64.17   52.9299  69km E of Petropavlovsk-Kamchatskiy, Russia   159.6696
# 4  10.00  -32.7096   159km SSW of L'Esperance Rock, New Zealand  -179.6688
#
#    Magnitude       UTC_Time Date Date_Time
# 0        4.8  1483218482160
# 1        4.9  1483196482860
# 2        4.9  1483132114060
# 3        4.9  1483118003100
# 4        4.8  1483103480780

# %%
def convert_to_date(string):
    date = datetime.fromtimestamp(string/1000)
    date_data = datetime.date(date)
    date_data = str(date_data).replace("-","")
    return (date_data)

def convert_to_date_time(string):
    date = datetime.fromtimestamp(string/1000)
    return (date)

# %%
for index, row in data_df.iterrows():
    data_df['Date_Time'] = data_df['UTC_Time'].apply(convert_to_date_time)
    data_df['Date'] = data_df['UTC_Time'].apply(convert_to_date)

# %%
data_df
# Out:
#        Depth  Latitude                                           Location  \
# 0       8.26   26.0580                         89km ESE of Haebaru, Japan
# 1      67.06    5.3647                  78km WSW of Banda Aceh, Indonesia
# 2      10.00   13.3141             119km ESE of Yigo Mayor's Office, Guam
# 3      64.17   52.9299        69km E of Petropavlovsk-Kamchatskiy, Russia
# 4      10.00  -32.7096         159km SSW of L'Esperance Rock, New Zealand
# 5      10.00  -22.0388                         137km SE of `Ohonua, Tonga
# 6     198.27  -21.1453                      204km SSE of Isangel, Vanuatu
# 7      21.72   -5.3851                 101km S of Taron, Papua New Guinea
# 8     118.41   36.0937                     53km S of Farkhar, Afghanistan
# 9     203.51   25.2398                        55km NNW of Iwo Jima, Japan
# 10     56.04   43.7070                         69km E of Shikotan, Russia
# 11     30.49   37.1945                           36km SE of Kalaleh, Iran
# ...

# %%
len(data_df['Location'])
# Out:
# 6885

# %%
data_df.to_csv('earthquake_data1.csv')

# %%
# data_pd = pd.read_csv('earthquake_data1.csv')

# %%
# len(data_pd['Location'])

# %%
# data_pd.head()

# %%
# data_pd['Temp(F)'] = ''
# data_pd['URL'] =''

# %%
# data_pd

# %%
# plt.scatter(data_df['Magnitude'],data_df['Depth'])
# plt.title('Earthquake Magnitude vs. Earthquake Depth')
# plt.xlabel('Magnitude')
# plt.ylabel('Depth')

# plt.savefig('Temp vs Lat.png')

# plt.show()

# %%
# row_count = 1

# weather_url = 'http://api.wunderground.com/api/962ddf6576040f5b/history_'

# for row in data_pd.itertuples():
        
#     if row_count <=10:
        
#         query_url = weather_url + str(row.Date) + '/q/' + str(row.Latitude) + ',' + str(row.Longitude)
        
#         weather_data = rq.get(query_url).json()
        
#         row.URL = query_url
        
#         if (weather_data.status_code == rq.codes.ok) == 'True':
            
#             row.Temp(F) = weather_data['history']['dailysummary'][0]['maxtempi']
            
# #             row.Temp(F) = temp_data
            
#             row_count =+ 1
        
#         else:
            
#             row.Temp(F) = 'None'
            
#             row_count =+ 1
                
#     else:
        
#         row_count = 1
#         time.sleep(10)

# %%
# row_count = 1

# weather_url = 'http://api.wunderground.com/api/962ddf6576040f5b/history_'

# for row in data_pd.iterrows():
        
#     if row_count <=10:
        
#         query_url = weather_url + data_pd.loc[index,'Date'] + '/q/' + data_pd.loc[index,'Latitude'] + ',' + data_pd.loc[index,'Longitude']
        
#         weather_data = rq.get(query_url).json()
        
#         data_pd.loc[index,'URL'] = query_url
        
#         if (weather_data.status_code == rq.codes.ok) == 'True':
            
#             temp_data = weather_data['history']['dailysummary'][0]['maxtempi']
            
#             data_pd.loc[index,'Temp(F)'] = temp_data
            
#             row_count =+ 1
        
#         else:
            
#             data_pd.loc[index,'Temp(F)'] = 'None'
            
#             row_count =+ 1
                
#     else:
        
#         row_count = 1
#         time.sleep(40)

# %%
# os.system('touch earthquake_weather_ex.csv')
# data_pd.to_csv('earthquake_weather_ex.csv')

# https://www.wunderground.com/history/wmo/91502/2012/12/31/DailyHistory.html?req_city=Amun&req_state=NSA&req_statename=Papua+New+Guinea&reqdb.wmo=91502

# http://api.wunderground.com/api/962ddf6576040f5b/geolookup/q/-5.9993,153.7578.json
# data_pd.to_csv('earthquake_weather_data.csv')
