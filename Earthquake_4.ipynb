# %%
import requests as rq
import json
import datetime
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import time as time
import csv
import os

from datetime import datetime

os.system('touch earthquake_data4.csv')
# Out:
# 1

# %%
all_data = []
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2017-01-01&minmagnitude=4.15&maxmagnitude=4.35'
earthquake_data = rq.get(url).json()

for i in range(0,len(earthquake_data['features'])):
    all_data.append({'Location':earthquake_data['features'][i]['properties']['place'], 'Magnitude':earthquake_data['features'][i]['properties']['mag'],'UTC_Time':earthquake_data['features'][i]['properties']['time'],'Longitude':earthquake_data['features'][i]['geometry']['coordinates'][0],'Latitude':earthquake_data['features'][i]['geometry']['coordinates'][1], 'Depth':earthquake_data['features'][i]['geometry']['coordinates'][2]})

print(all_data)
# Out:
# [{'Location': '116km E of Esso, Russia', 'Magnitude': 4.3, 'UTC_Time': 1483200956660, 'Longitude': 160.558, 'Latitude': 56.0498, 'Depth': 138.19}, {'Location': '56km N of Neiafu, Tonga', 'Magnitude': 4.3, 'UTC_Time': 1483190983200, 'Longitude': -173.9993, 'Latitude': -18.1405, 'Depth': 124.52}, {'Location': '91km SE of Hihifo, Tonga', 'Magnitude': 4.3, 'UTC_Time': 1483180584160, 'Longitude': -173.2415, 'Latitude': -16.6097, 'Depth': 35}, {'Location': '55km SW of Sabtang, Philippines', 'Magnitude': 4.2, 'UTC_Time': 1483175996630, 'Longitude': 121.5503, 'Latitude': 19.936, 'Depth': 43.73}, {'Location': '2km NNW of Ilo, Peru', 'Magnitude': 4.2, 'UTC_Time': 1483158448650, 'Longitude': -71.3453, 'Latitude': -17.614, 'Depth': 69.12}, {'Location': '99km WSW of Gerash, Iran', 'Magnitude': 4.2, 'UTC_Time': 1483129077430, 'Longitude': 53.2217, 'Latitude': 27.2869, 'Depth': 10}, {'Location': '34km SSW of Agrihan, Northern Mariana Islands', 'Magnitude': 4.3, 'UTC_Time': 1483096908050, 'Longitude': 145.5116, 'Latitude': 18.4974, 'Depth': 214.66}, {'Location': '20km ENE of Shagonar, Russia', 'Magnitude': 4.3, 'UTC_Time': 1483090926090, 'Longitude': 93.0818, 'Latitude': 51.5943, 'Depth': 10}, {'Location': '69km SE of Ofunato, Japan', 'Magnitude': 4.3, 'UTC_Time': 1483067027610, 'Longitude': 142.2602, 'Latitude': 38.6072, 'Depth': 46.64}, {'Location': '30km E of Yilan, Taiwan', 'Magnitude': 4.3, 'UTC_Time': 1483057851430, 'Longitude': 122.0522, 'Latitude': 24.7983, 'Depth': 77.21}, {'Location': '144km S of Koroni, Greece', 'Magnitude': 4.3, 'UTC_Time': 1483043034970, 'Longitude': 21.9432, 'Latitude': 35.494, 'Depth': 10}, {'Location': '28km SSE of Campoverde, Peru', 'Magnitude': 4.2, 'UTC_Time': 1483035746380, 'Longitude': -74.681, 'Latitude': -8.6997, 'Depth': 147.63}, {'Location': '216km SE of Sarangani, Philippines', 'Magnitude': 4.3, 'UTC_Time': 1483022253160, 'Longitude': 126.7909, 'Latitude': 3.9723, 'Depth': 82.3}, {'Location': '184km W of Panguna, Papua New Guinea', 'Magnitude': 4.3, 'UTC_Time': 1483016615070, 'Longitude': 153.8463, 'Latitude': -6.6122, 'Depth': 10}, {'Location': 'West Chile Rise', 'Magnitude': 4.3, 'UTC_Time': 1483009292410, 'Longitude': -94.2505, 'Latitude': -38.0886, 'Depth': 10}, {'Location': '107km SSW of Bengkulu, Indonesia', 'Magnitude': 4.3, 'UTC_Time': 1482999404850, 'Longitude': 101.7366, 'Latitude': -4.6133, 'Depth': 31.98}, {'Location': '24km NNE of Macas, Ecuador', 'Magnitude': 4.2, 'UTC_Time': 1482984140630, 'Longitude': -78.0353, 'Latitude': -2.1085, 'Depth': 134.25}, {'Location': '118km SSW of Bengkulu, Indonesia', 'Magnitude': 4.3, 'UTC_Time': 1482974546280, 'Longitude': 101.697, 'Latitude': -4.7053, 'Depth': 31.82}, {'Location': '19km SSW of San Marcos, Mexico', 'Magnitude': 4.2, 'UTC_Time': 1482974252540, 'Longitude': -99.4476, 'Latitude': 16.654, 'Depth': 10}, {'Location': '138km E of Hihifo, Tonga', 'Magnitude': 4.3, 'UTC_Time': 1482963656510, 'Longitude': -172.4755, 'Latitude': -15.7201, 'Depth': 10}, {'Location': '289km NW of Ozernovskiy, Russia', 'Magnitude': 4.3, 'UTC_Time': 1482957641270, 'Longitude': 153.8191, 'Latitude': 53.5105, 'Depth': 475.73}, {'Location': '33km NNW of Kirakira, Solomon Islands', 'Magnitude': 4.3, 'UTC_Time': 1482946286390, 'Longitude': 161.7943, 'Latitude': -10.1826, 'Depth': 75.78}, {'Location': '297km ESE of Lambasa, Fiji', 'Magnitude': 4.2, 'UTC_Time': 1482941277660, 'Longitude': -178.175, 'Latitude': -17.7213, 'Depth': 606.79}, {'Location': '42km E of Ndoi Island, Fiji', 'Magnitude': 4.3, 'UTC_Time': 1482938070250, 'Longitude': -178.2898, 'Latitude': -20.6257, 'Depth': 545.72}, {'Location': '225km S of False Pass, Alaska', 'Magnitude': 4.3, 'UTC_Time': 1482929204970, 'Longitude': -162.9064, 'Latitude': 52.8468, 'Depth': 29.3}, {'Location': '192km SSE of Taron, Papua New Guinea', 'Magnitude': 4.2, 'UTC_Time': 1482892796080, 'Longitude': 153.6176, 'Latitude': -6.1072, 'Depth': 10}, {'Location': '170km SSE of Taron, Papua New Guinea', 'Magnitude': 4.2, 'UTC_Time': 148 ...

# %%
data_df = pd.DataFrame(all_data)
data_df.head()
# Out:
#     Depth  Latitude                         Location  Longitude  Magnitude  \
# 0  138.19   56.0498          116km E of Esso, Russia   160.5580        4.3
# 1  124.52  -18.1405          56km N of Neiafu, Tonga  -173.9993        4.3
# 2   35.00  -16.6097         91km SE of Hihifo, Tonga  -173.2415        4.3
# 3   43.73   19.9360  55km SW of Sabtang, Philippines   121.5503        4.2
# 4   69.12  -17.6140             2km NNW of Ilo, Peru   -71.3453        4.2
#
#         UTC_Time
# 0  1483200956660
# 1  1483190983200
# 2  1483180584160
# 3  1483175996630
# 4  1483158448650

# %%
data_df['Date'] = ''
data_df['Date_Time'] = '' 
data_df.head()
# Out:
#     Depth  Latitude                         Location  Longitude  Magnitude  \
# 0  138.19   56.0498          116km E of Esso, Russia   160.5580        4.3
# 1  124.52  -18.1405          56km N of Neiafu, Tonga  -173.9993        4.3
# 2   35.00  -16.6097         91km SE of Hihifo, Tonga  -173.2415        4.3
# 3   43.73   19.9360  55km SW of Sabtang, Philippines   121.5503        4.2
# 4   69.12  -17.6140             2km NNW of Ilo, Peru   -71.3453        4.2
#
#         UTC_Time Date Date_Time
# 0  1483200956660
# 1  1483190983200
# 2  1483180584160
# 3  1483175996630
# 4  1483158448650

# %%
len(data_df['Location'])
# Out:
# 16673

# %%
def convert_to_date(string):
    date = datetime.fromtimestamp(string/1000)
    date_data = datetime.date(date)
    date_data = str(date_data).replace("-","")
    return (date_data)

def convert_to_date_time(string):
    date = datetime.fromtimestamp(string/1000)
    return (date)

# %%
for index, row in data_df.iterrows():
    data_df['Date_Time'] = data_df['UTC_Time'].apply(convert_to_date_time)
    data_df['Date'] = data_df['UTC_Time'].apply(convert_to_date)

# %%
data_df
# Out:
#         Depth  Latitude                                       Location  \
# 0      138.19   56.0498                        116km E of Esso, Russia
# 1      124.52  -18.1405                        56km N of Neiafu, Tonga
# 2       35.00  -16.6097                       91km SE of Hihifo, Tonga
# 3       43.73   19.9360                55km SW of Sabtang, Philippines
# 4       69.12  -17.6140                           2km NNW of Ilo, Peru
# 5       10.00   27.2869                       99km WSW of Gerash, Iran
# 6      214.66   18.4974  34km SSW of Agrihan, Northern Mariana Islands
# 7       10.00   51.5943                   20km ENE of Shagonar, Russia
# 8       46.64   38.6072                      69km SE of Ofunato, Japan
# 9       77.21   24.7983                        30km E of Yilan, Taiwan
# 10      10.00   35.4940                      144km S of Koroni, Greece
# 11     147.63   -8.6997                   28km SSE of Campoverde, Peru
# 12      82.30    3.9723             216km SE of Sarangani, Philippines
# 13      10.00   -6.6122           184km W of Panguna, Papua New Guinea
# 14      10.00  -38.0886                                West Chile Rise
# 15      31.98   -4.6133               107km SSW of Bengkulu, Indonesia
# 16     134.25   -2.1085                     24km NNE of Macas, Ecuador
# 17      31.82   -4.7053               118km SSW of Bengkulu, Indonesia
# 18      10.00   16.6540                 19km SSW of San Marcos, Mexico
# 19      10.00  -15.7201                       138km E of Hihifo, Tonga
# 20     475.73   53.5105                289km NW of Ozernovskiy, Russia
# 21      75.78  -10.1826          33km NNW of Kirakira, Solomon Islands
# 22     606.79  -17.7213                     297km ESE of Lambasa, Fiji
# 23     545.72  -20.6257                    42km E of Ndoi Island, Fiji
# 24      29.30   52.8468                  225km S of False Pass, Alaska
# 25      10.00   -6.1072           192km SSE of Taron, Papua New Guinea
# 26      10.00   -5.8946           170km SSE of Taron, Papua New Guinea
# 27      34.43   37.7379                28km NNW of Farkhor, Tajikistan
# 28      10.00  -10.8390            43km S of Kirakira, Solomon Islands
# 29      10.00   44.0166                        Off the coast of Oregon
# ...       ...       ...                                            ...
# 16643   10.00  -11.0290                                Solomon Islands
# 16644   22.50   -1.2440                            Sulawesi, Indonesia
# 16645    5.40   37.9940                Turkey-Syria-Iraq border region
# 16646   35.00   -4.8600          Bougainville region, Papua New Guinea
# 16647   45.60   53.5230          Fox Islands, Aleutian Islands, Alaska
