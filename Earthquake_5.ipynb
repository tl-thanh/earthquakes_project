# %%
import requests as rq
import json
import datetime
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import time as time
import csv
import os

from datetime import datetime

os.system('touch earthquake_data5.csv')
# Out:
# 1

# %%
all_data = []
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2017-01-01&minmagnitude=4&maxmagnitude=4.149'
earthquake_data = rq.get(url).json()

for i in range(0,len(earthquake_data['features'])):
    all_data.append({'Location':earthquake_data['features'][i]['properties']['place'], 'Magnitude':earthquake_data['features'][i]['properties']['mag'],'UTC_Time':earthquake_data['features'][i]['properties']['time'],'Longitude':earthquake_data['features'][i]['geometry']['coordinates'][0],'Latitude':earthquake_data['features'][i]['geometry']['coordinates'][1], 'Depth':earthquake_data['features'][i]['geometry']['coordinates'][2]})

print(all_data)
# Out:
# [{'Location': '97km WNW of Kota Ternate, Indonesia', 'Magnitude': 4, 'UTC_Time': 1483204971700, 'Longitude': 126.5326, 'Latitude': 1.0439, 'Depth': 42.38}, {'Location': 'South of the Fiji Islands', 'Magnitude': 4, 'UTC_Time': 1483193822890, 'Longitude': 179.7307, 'Latitude': -25.0114, 'Depth': 513.31}, {'Location': '104km NW of Kish, Iran', 'Magnitude': 4.1, 'UTC_Time': 1483127260410, 'Longitude': 53.1842, 'Latitude': 27.1255, 'Depth': 43.74}, {'Location': '9km SSW of Malabugas, Philippines', 'Magnitude': 4.1, 'UTC_Time': 1483110065480, 'Longitude': 122.7357, 'Latitude': 9.2912, 'Depth': 69.42}, {'Location': '3km WNW of Khrisokhorion, Greece', 'Magnitude': 4, 'UTC_Time': 1483062985380, 'Longitude': 24.6776, 'Latitude': 40.9443, 'Depth': 10}, {'Location': '33km W of Ashkasham, Afghanistan', 'Magnitude': 4.1, 'UTC_Time': 1483051586260, 'Longitude': 71.164, 'Latitude': 36.6703, 'Depth': 209.12}, {'Location': '22km NNW of Taupo, New Zealand', 'Magnitude': 4.1, 'UTC_Time': 1483009133030, 'Longitude': 176.0231, 'Latitude': -38.4861, 'Depth': 169.41}, {'Location': '68km W of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482969114760, 'Longitude': -74.4594, 'Latitude': -43.1386, 'Depth': 19.42}, {'Location': '64km WSW of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482963521780, 'Longitude': -74.3477, 'Latitude': -43.35, 'Depth': 15.15}, {'Location': '32km E of Junlian, China', 'Magnitude': 4.1, 'UTC_Time': 1482926590390, 'Longitude': 104.8434, 'Latitude': 28.1681, 'Depth': 10}, {'Location': '238km N of Frontera, Mexico', 'Magnitude': 4.1, 'UTC_Time': 1482896267370, 'Longitude': -92.8578, 'Latitude': 20.7282, 'Depth': 15.02}, {'Location': '62km ENE of Taron, Papua New Guinea', 'Magnitude': 4.1, 'UTC_Time': 1482870796340, 'Longitude': 153.5682, 'Latitude': -4.2851, 'Depth': 105.87}, {'Location': '139km ESE of Iquique, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482837737740, 'Longitude': -68.8377, 'Latitude': -20.4826, 'Depth': 113.86}, {'Location': 'Off the coast of Oregon', 'Magnitude': 4.1, 'UTC_Time': 1482832356970, 'Longitude': -128.6385, 'Latitude': 44.0873, 'Depth': 10}, {'Location': '71km E of Cape Yakataga, Alaska', 'Magnitude': 4, 'UTC_Time': 1482796790290, 'Longitude': -141.1619, 'Latitude': 60.1571, 'Depth': 12.5}, {'Location': '174km NE of Ndoi Island, Fiji', 'Magnitude': 4.1, 'UTC_Time': 1482750598020, 'Longitude': -177.536, 'Latitude': -19.517, 'Depth': 555.76}, {'Location': '10km SW of San Andres, Colombia', 'Magnitude': 4, 'UTC_Time': 1482742075160, 'Longitude': -72.912, 'Latitude': 6.7446, 'Depth': 157.41}, {'Location': '111km WNW of La Ligua, Chile', 'Magnitude': 4, 'UTC_Time': 1482716074240, 'Longitude': -72.3683, 'Latitude': -32.1807, 'Depth': 24.92}, {'Location': '52km WSW of Finschhafen, Papua New Guinea', 'Magnitude': 4.1, 'UTC_Time': 1482715493400, 'Longitude': 147.4589, 'Latitude': -6.851, 'Depth': 10}, {'Location': '74km WSW of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482713008950, 'Longitude': -74.487, 'Latitude': -43.3363, 'Depth': 21.45}, {'Location': '108km W of San Antonio de los Cobres, Argentina', 'Magnitude': 4, 'UTC_Time': 1482707133600, 'Longitude': -67.3808, 'Latitude': -24.0854, 'Depth': 196.42}, {'Location': '53km S of El Rosario, El Salvador', 'Magnitude': 4, 'UTC_Time': 1482707018480, 'Longitude': -88.9792, 'Latitude': 13.0196, 'Depth': 29.54}, {'Location': '86km WSW of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482702955650, 'Longitude': -74.5914, 'Latitude': -43.4272, 'Depth': 7.63}, {'Location': '100km W of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482698891670, 'Longitude': -74.8351, 'Latitude': -43.2794, 'Depth': 14.24}, {'Location': '69km WSW of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482682076730, 'Longitude': -74.452, 'Latitude': -43.2379, 'Depth': 14.19}, {'Location': '56km WSW of Puerto Quellon, Chile', 'Magnitude': 4.1, 'UTC_Time': 1482681602610, 'Longitude': -74.2277, 'Latitude': -43.3561, 'Depth': 16.06}, {'Locatio ...

# %%
data_df = pd.DataFrame(all_data)
data_df.head()
# Out:
#     Depth  Latitude                             Location  Longitude  \
# 0   42.38    1.0439  97km WNW of Kota Ternate, Indonesia   126.5326
# 1  513.31  -25.0114            South of the Fiji Islands   179.7307
# 2   43.74   27.1255               104km NW of Kish, Iran    53.1842
# 3   69.42    9.2912    9km SSW of Malabugas, Philippines   122.7357
# 4   10.00   40.9443     3km WNW of Khrisokhorion, Greece    24.6776
#
#    Magnitude       UTC_Time
# 0        4.0  1483204971700
# 1        4.0  1483193822890
# 2        4.1  1483127260410
# 3        4.1  1483110065480
# 4        4.0  1483062985380

# %%
data_df['Date'] = ''
data_df['Date_Time'] = '' 
data_df.head()
# Out:
#     Depth  Latitude                             Location  Longitude  \
# 0   42.38    1.0439  97km WNW of Kota Ternate, Indonesia   126.5326
# 1  513.31  -25.0114            South of the Fiji Islands   179.7307
# 2   43.74   27.1255               104km NW of Kish, Iran    53.1842
# 3   69.42    9.2912    9km SSW of Malabugas, Philippines   122.7357
# 4   10.00   40.9443     3km WNW of Khrisokhorion, Greece    24.6776
#
#    Magnitude       UTC_Time Date Date_Time
# 0        4.0  1483204971700
# 1        4.0  1483193822890
# 2        4.1  1483127260410
# 3        4.1  1483110065480
# 4        4.0  1483062985380

# %%
len(data_df['Location'])
# Out:
# 11408

# %%
def convert_to_date(string):
    date = datetime.fromtimestamp(string/1000)
    date_data = datetime.date(date)
    date_data = str(date_data).replace("-","")
    return (date_data)

def convert_to_date_time(string):
    date = datetime.fromtimestamp(string/1000)
    return (date)

# %%
for index, row in data_df.iterrows():
    data_df['Date_Time'] = data_df['UTC_Time'].apply(convert_to_date_time)
    data_df['Date'] = data_df['UTC_Time'].apply(convert_to_date)

# %%
data_df
# Out:
#          Depth   Latitude                                           Location  \
# 0       42.380   1.043900                97km WNW of Kota Ternate, Indonesia
# 1      513.310 -25.011400                          South of the Fiji Islands
# 2       43.740  27.125500                             104km NW of Kish, Iran
# 3       69.420   9.291200                  9km SSW of Malabugas, Philippines
# 4       10.000  40.944300                   3km WNW of Khrisokhorion, Greece
# 5      209.120  36.670300                   33km W of Ashkasham, Afghanistan
# 6      169.410 -38.486100                     22km NNW of Taupo, New Zealand
# 7       19.420 -43.138600                    68km W of Puerto Quellon, Chile
# 8       15.150 -43.350000                  64km WSW of Puerto Quellon, Chile
# 9       10.000  28.168100                           32km E of Junlian, China
# 10      15.020  20.728200                        238km N of Frontera, Mexico
# 11     105.870  -4.285100                62km ENE of Taron, Papua New Guinea
# 12     113.860 -20.482600                        139km ESE of Iquique, Chile
# 13      10.000  44.087300                            Off the coast of Oregon
# 14      12.500  60.157100                    71km E of Cape Yakataga, Alaska
# 15     555.760 -19.517000                      174km NE of Ndoi Island, Fiji
# 16     157.410   6.744600                    10km SW of San Andres, Colombia
# 17      24.920 -32.180700                       111km WNW of La Ligua, Chile
# 18      10.000  -6.851000          52km WSW of Finschhafen, Papua New Guinea
# 19      21.450 -43.336300                  74km WSW of Puerto Quellon, Chile
# 20     196.420 -24.085400    108km W of San Antonio de los Cobres, Argentina
# 21      29.540  13.019600                  53km S of El Rosario, El Salvador
# 22       7.630 -43.427200                  86km WSW of Puerto Quellon, Chile
# 23      14.240 -43.279400                   100km W of Puerto Quellon, Chile
# 24      14.190 -43.237900                  69km WSW of Puerto Quellon, Chile
# 25      16.060 -43.356100                  56km WSW of Puerto Quellon, Chile
# 26      21.960 -43.237200                  65km WSW of Puerto Quellon, Chile
# 27      59.170  -6.075400             18km NNW of Kandrian, Papua New Guinea
# 28     418.250  18.585100      38km WSW of Agrihan, Northern Mariana Islands
# 29     111.110  -4.407800                  44km E of Taron, Papua New Guinea
# ...        ...        ...                                                ...
# 11378   35.000  -8.844000                      Kepulauan Tanimbar, Indonesia
# 11379   10.000  25.431000                                 Gulf of California
# 11380   21.400  14.413000                   off the coast of Chiapas, Mexico
# 11381   35.000  12.002000                                        Guam region
# 11382   21.700  16.040000                            offshore Oaxaca, Mexico
# 11383   19.400 -37.585000  off the east coast of the North Island of New ...
# 11384   32.000 -39.534000                        North Island of New Zealand
# 11385   30.600 -36.957000  off the east coast of the North Island of New ...
# 11386   35.000  -5.539000                                          Banda Sea
