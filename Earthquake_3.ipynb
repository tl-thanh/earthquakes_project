# %%
import requests as rq
import json
import datetime
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import time as time
import csv
import os

from datetime import datetime

os.system('touch earthquake_data3.csv')
# Out:
# 1

# %%
all_data = []
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2012-01-01&endtime=2017-01-01&minmagnitude=4.35&maxmagnitude=4.54'
earthquake_data = rq.get(url).json()

for i in range(0,len(earthquake_data['features'])):
    all_data.append({'Location':earthquake_data['features'][i]['properties']['place'], 'Magnitude':earthquake_data['features'][i]['properties']['mag'],'UTC_Time':earthquake_data['features'][i]['properties']['time'],'Longitude':earthquake_data['features'][i]['geometry']['coordinates'][0],'Latitude':earthquake_data['features'][i]['geometry']['coordinates'][1], 'Depth':earthquake_data['features'][i]['geometry']['coordinates'][2]})

print(all_data)
# Out:
# [{'Location': '60km S of Ndoi Island, Fiji', 'Magnitude': 4.4, 'UTC_Time': 1483179810280, 'Longitude': -178.7428, 'Latitude': -21.1939, 'Depth': 562.55}, {'Location': '19km SW of Agrihan, Northern Mariana Islands', 'Magnitude': 4.5, 'UTC_Time': 1483177318440, 'Longitude': 145.554, 'Latitude': 18.6269, 'Depth': 179.09}, {'Location': '165km SSE of Taron, Papua New Guinea', 'Magnitude': 4.5, 'UTC_Time': 1483171838820, 'Longitude': 153.5421, 'Latitude': -5.875, 'Depth': 10}, {'Location': '77km SSE of Kokopo, Papua New Guinea', 'Magnitude': 4.4, 'UTC_Time': 1483125369780, 'Longitude': 152.4766, 'Latitude': -5.0199, 'Depth': 10}, {'Location': "102km NE of L'Esperance Rock, New Zealand", 'Magnitude': 4.4, 'UTC_Time': 1483124734290, 'Longitude': -178.1429, 'Latitude': -30.7747, 'Depth': 10}, {'Location': '185km N of Sola, Vanuatu', 'Magnitude': 4.4, 'UTC_Time': 1483123665880, 'Longitude': 167.2556, 'Latitude': -12.2303, 'Depth': 230.86}, {'Location': '8km NNW of Pocito, Argentina', 'Magnitude': 4.5, 'UTC_Time': 1483112904320, 'Longitude': -68.6146, 'Latitude': -31.6078, 'Depth': 107.61}, {'Location': "85km NNE of L'Esperance Rock, New Zealand", 'Magnitude': 4.4, 'UTC_Time': 1483109518370, 'Longitude': -178.7121, 'Latitude': -30.6792, 'Depth': 14.46}, {'Location': '38km NNE of Baja Mar, Honduras', 'Magnitude': 4.4, 'UTC_Time': 1483096985350, 'Longitude': -87.7557, 'Latitude': 16.2179, 'Depth': 22.6}, {'Location': '86km ESE of Ndoi Island, Fiji', 'Magnitude': 4.5, 'UTC_Time': 1483094283740, 'Longitude': -177.9226, 'Latitude': -20.9221, 'Depth': 470.03}, {'Location': 'South of Panama', 'Magnitude': 4.5, 'UTC_Time': 1483083287310, 'Longitude': -82.75, 'Latitude': 3.953, 'Depth': 10}, {'Location': '45km SSE of Tolotangga, Indonesia', 'Magnitude': 4.4, 'UTC_Time': 1483080080480, 'Longitude': 118.7325, 'Latitude': -9.1597, 'Depth': 105.58}, {'Location': 'South of the Fiji Islands', 'Magnitude': 4.4, 'UTC_Time': 1483042477430, 'Longitude': -179.2395, 'Latitude': -24.4865, 'Depth': 535.57}, {'Location': '67km W of Kirakira, Solomon Islands', 'Magnitude': 4.5, 'UTC_Time': 1483040550920, 'Longitude': 161.3117, 'Latitude': -10.341, 'Depth': 35}, {'Location': '36km SE of Chazuta, Peru', 'Magnitude': 4.5, 'UTC_Time': 1483025923050, 'Longitude': -75.9423, 'Latitude': -6.845, 'Depth': 4.49}, {'Location': 'Western Indian-Antarctic Ridge', 'Magnitude': 4.4, 'UTC_Time': 1483025124490, 'Longitude': 124.8704, 'Latitude': -49.4486, 'Depth': 10}, {'Location': '11km SSE of San Antonio, Chile', 'Magnitude': 4.4, 'UTC_Time': 1483001421220, 'Longitude': -71.5737, 'Latitude': -33.6842, 'Depth': 43.26}, {'Location': '65km W of Pathein, Burma', 'Magnitude': 4.4, 'UTC_Time': 1482990723910, 'Longitude': 94.12, 'Latitude': 16.7482, 'Depth': 14.89}, {'Location': '60km WSW of Kirakira, Solomon Islands', 'Magnitude': 4.4, 'UTC_Time': 1482988259990, 'Longitude': 161.4298, 'Latitude': -10.7086, 'Depth': 37.33}, {'Location': '149km ESE of Mohean, India', 'Magnitude': 4.4, 'UTC_Time': 1482987933520, 'Longitude': 94.4877, 'Latitude': 7.2815, 'Depth': 22.86}, {'Location': '14km NW of Hitachi, Japan', 'Magnitude': 4.4, 'UTC_Time': 1482986472810, 'Longitude': 140.5141, 'Latitude': 36.6781, 'Depth': 36.17}, {'Location': '42km SW of Brooklyn, New Zealand', 'Magnitude': 4.4, 'UTC_Time': 1482980420650, 'Longitude': 174.4604, 'Latitude': -41.6329, 'Depth': 25.37}, {'Location': '50km E of Port-Olry, Vanuatu', 'Magnitude': 4.5, 'UTC_Time': 1482949731210, 'Longitude': 167.5075, 'Latitude': -14.9659, 'Depth': 100.57}, {'Location': '42km SSE of Ndoi Island, Fiji', 'Magnitude': 4.5, 'UTC_Time': 1482944948390, 'Longitude': -178.5336, 'Latitude': -21.0034, 'Depth': 511}, {'Location': '50km ENE of General Luna, Philippines', 'Magnitude': 4.5, 'UTC_Time': 1482921835690, 'Longitude': 126.5579, 'Latitude': 10.0133, 'Depth': 42.29}, {'Location': '70km E of Contamana, Peru', 'Magnitude': 4.4, 'UTC_Time': 1482920316160, 'Longitude': -74.3831, 'Latitude': -7.286, 'Depth': 172.54}, {'Location': '103 ...

# %%
data_df = pd.DataFrame(all_data)
data_df.head()
# Out:
#     Depth  Latitude                                      Location  Longitude  \
# 0  562.55  -21.1939                   60km S of Ndoi Island, Fiji  -178.7428
# 1  179.09   18.6269  19km SW of Agrihan, Northern Mariana Islands   145.5540
# 2   10.00   -5.8750          165km SSE of Taron, Papua New Guinea   153.5421
# 3   10.00   -5.0199          77km SSE of Kokopo, Papua New Guinea   152.4766
# 4   10.00  -30.7747     102km NE of L'Esperance Rock, New Zealand  -178.1429
#
#    Magnitude       UTC_Time
# 0        4.4  1483179810280
# 1        4.5  1483177318440
# 2        4.5  1483171838820
# 3        4.4  1483125369780
# 4        4.4  1483124734290

# %%
data_df['Date'] = ''
data_df['Date_Time'] = '' 
data_df.head()
# Out:
#     Depth  Latitude                                      Location  Longitude  \
# 0  562.55  -21.1939                   60km S of Ndoi Island, Fiji  -178.7428
# 1  179.09   18.6269  19km SW of Agrihan, Northern Mariana Islands   145.5540
# 2   10.00   -5.8750          165km SSE of Taron, Papua New Guinea   153.5421
# 3   10.00   -5.0199          77km SSE of Kokopo, Papua New Guinea   152.4766
# 4   10.00  -30.7747     102km NE of L'Esperance Rock, New Zealand  -178.1429
#
#    Magnitude       UTC_Time Date Date_Time
# 0        4.4  1483179810280
# 1        4.5  1483177318440
# 2        4.5  1483171838820
# 3        4.4  1483125369780
# 4        4.4  1483124734290

# %%
len(data_df['Location'])
# Out:
# 17849

# %%
def convert_to_date(string):
    date = datetime.fromtimestamp(string/1000)
    date_data = datetime.date(date)
    date_data = str(date_data).replace("-","")
    return (date_data)

def convert_to_date_time(string):
    date = datetime.fromtimestamp(string/1000)
    return (date)

# %%
for index, row in data_df.iterrows():
    data_df['Date_Time'] = data_df['UTC_Time'].apply(convert_to_date_time)
    data_df['Date'] = data_df['UTC_Time'].apply(convert_to_date)

# %%
data_df
# Out:
#         Depth  Latitude                                      Location  \
# 0      562.55  -21.1939                   60km S of Ndoi Island, Fiji
# 1      179.09   18.6269  19km SW of Agrihan, Northern Mariana Islands
# 2       10.00   -5.8750          165km SSE of Taron, Papua New Guinea
# 3       10.00   -5.0199          77km SSE of Kokopo, Papua New Guinea
# 4       10.00  -30.7747     102km NE of L'Esperance Rock, New Zealand
# 5      230.86  -12.2303                      185km N of Sola, Vanuatu
# 6      107.61  -31.6078                  8km NNW of Pocito, Argentina
# 7       14.46  -30.6792     85km NNE of L'Esperance Rock, New Zealand
# 8       22.60   16.2179                38km NNE of Baja Mar, Honduras
# 9      470.03  -20.9221                 86km ESE of Ndoi Island, Fiji
# 10      10.00    3.9530                               South of Panama
# 11     105.58   -9.1597             45km SSE of Tolotangga, Indonesia
# 12     535.57  -24.4865                     South of the Fiji Islands
# 13      35.00  -10.3410           67km W of Kirakira, Solomon Islands
# 14       4.49   -6.8450                      36km SE of Chazuta, Peru
# 15      10.00  -49.4486                Western Indian-Antarctic Ridge
# 16      43.26  -33.6842                11km SSE of San Antonio, Chile
# 17      14.89   16.7482                      65km W of Pathein, Burma
# 18      37.33  -10.7086         60km WSW of Kirakira, Solomon Islands
# 19      22.86    7.2815                    149km ESE of Mohean, India
# 20      36.17   36.6781                     14km NW of Hitachi, Japan
# 21      25.37  -41.6329              42km SW of Brooklyn, New Zealand
# 22     100.57  -14.9659                  50km E of Port-Olry, Vanuatu
# 23     511.00  -21.0034                 42km SSE of Ndoi Island, Fiji
# 24      42.29   10.0133         50km ENE of General Luna, Philippines
# 25     172.54   -7.2860                     70km E of Contamana, Peru
# 26      73.28   -6.0278       103km WNW of Kandrian, Papua New Guinea
# 27      10.00   29.4126                  29km WNW of Yongchuan, China
# 28     213.34   18.7338    3km S of Agrihan, Northern Mariana Islands
# 29      10.00  -18.2095               120km WSW of Port-Vila, Vanuatu
# ...       ...       ...                                           ...
# 17819   41.90   37.0760                         eastern Honshu, Japan
# 17820   49.10   37.1000                         eastern Honshu, Japan
# 17821   68.10   13.5510                            offshore Guatemala
# 17822  103.40   -7.5070               Kepulauan Barat Daya, Indonesia
